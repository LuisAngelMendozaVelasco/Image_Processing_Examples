# %% [markdown]
# # Extracting Image File Information

# %%
from PIL import Image
import aux_functions as aux_func

# %% [markdown]
# ## bearGlacier1980.png

# %%
image_1980 = Image.open("./images/bearGlacier1980.png")
display(image_1980)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1502x1121>

# %%
image_info_1980 = aux_func.get_image_info(image_1980)
for key, value in image_info_1980.items():
    print(f"{key:25}: {value}")
# Out:
# filename                 : ./images/bearGlacier1980.png
# format                   : PNG
# mode                     : P
# size                     : (1502, 1121)
# width                    : 1502
# height                   : 1121
# palette                  : <PIL.ImagePalette.ImagePalette object at 0x000001F78BB1BBE0>
# is_animated              : False
# n_frames                 : 1
# Acquisition Date         : 1980-06-05
# Satellite Sensor         : Landsat 3
# Keywords                 : Landsat, Earth Science, Visible Imagery, Satellite, Remote Sensing
# State                    : Alaska
# Province                 : None
# Country                  : None
# Source                   : USGS
# Visual Representation    : None
# Resolution               : None
# Original Source Metadata : http://earthexplorer.usgs.gov/metadata/3120/LM30740181980157AAA13?node=LRS
# Level 1T Data            : http://earthexplorer.usgs.gov/download/options/3120/LM30740181980157AAA13/
# Creation Time            : 05-Jun-1980 00:00:00

# %%
image_info_1980["Creation Time"]
# Out:
# '05-Jun-1980 00:00:00'

# %% [markdown]
# ## bearGlacier2011.png

# %%
image_2011 = Image.open("./images/bearGlacier2011.png")
display(image_2011)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1502x1121>

# %%
image_info_2011 = aux_func.get_image_info(image_2011)
for key, value in image_info_2011.items():
    print(f"{key:25}: {value}")
# Out:
# filename                 : ./images/bearGlacier2011.png
# format                   : PNG
# mode                     : P
# size                     : (1502, 1121)
# width                    : 1502
# height                   : 1121
# palette                  : <PIL.ImagePalette.ImagePalette object at 0x000001F78BB54760>
# is_animated              : False
# n_frames                 : 1
# Acquisition Date         : 2011-05-13
# Satellite Sensor         : Landsat 7
# Keywords                 : Landsat, Earth Science, Visible Imagery, Satellite, Remote Sensing
# State                    : Alaska
# Province                 : None
# Country                  : None
# Source                   : USGS
# Visual Representation    : None
# Resolution               : None
# Original Source Metadata : https://earthexplorer.usgs.gov/metadata/12267/LE70680182011133EDC00?node=LRS
# Level 1T Data            : https://earthexplorer.usgs.gov/download/options/12267/LE70680182011133EDC00/
# Creation Time            : 13-May-2011 00:00:00

# %%
image_info_2011["Creation Time"]
# Out:
# '13-May-2011 00:00:00'
